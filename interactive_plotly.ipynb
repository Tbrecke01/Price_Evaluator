# %%
import pandas as pd
import numpy as np
import sys
# !{sys.executable} -m pip install plotly
import plotly.graph_objects as go

# %%
from sqlalchemy import create_engine
url = "postgresql://postgres:MickeyTheAnimal!@final-project.crnuve3iih8x.us-east-1.rds.amazonaws.com:5432/postgres"

engine = create_engine(url)
connect = engine.connect()

query = "SELECT * FROM price_data"

df = pd.read_sql(query, con=connect)
df
# Out:
#        index                    id  prices_amountmax  prices_amountmin  \
# 0          0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1          1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2          2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3          3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4          4  AVpgMuGwLJeJML43KY_c             66.99             66.99
# ...      ...                   ...               ...               ...
# 14587  14587  AVpgibRDLJeJML43PTZX             65.99             65.99
# 14588  14588  AVpgibRDLJeJML43PTZX             58.99             58.99
# 14589  14589  AVpgibRDLJeJML43PTZX             58.49             58.49
# 14590  14590  AVpgibRDLJeJML43PTZX             77.98             77.98
# 14591  14591  AVpgibRDLJeJML43PTZX             71.95             71.95
#
#       prices_availability prices_condition prices_currency prices_dateseen  \
# ...

# %%
df.set_index('prices_dateseen', inplace=True)

# %%
display(df.T)
# Out:
# prices_dateseen                                             2017-03-30  \
# index                                                                0
# id                                                AVphzgbJLJeJML43fA0o
# prices_amountmax                                                104.99
# prices_amountmin                                                104.99
# prices_availability                                               True
# prices_condition                                                   New
# prices_currency                                                    USD
# prices_issale                                                    False
# prices_merchant                                            Bestbuy.com
# prices_shipping                                                   None
# prices_sourceurls    http://www.bestbuy.com/site/sanus-tv-wall-moun...
# asins                                                       B00C78VIUE
# ...

# %%
df_grouped=df.groupby('prices_dateseen').sum()
df_grouped
# Out:
#                   index  prices_amountmax  prices_amountmin  prices_issale
# prices_dateseen
# 2014-05-30        22011             89.38             89.38              1
# 2014-08-23        11969           1048.00           1048.00              0
# 2014-08-30         5829            179.99            179.99              0
# 2014-08-31          564            251.80            251.80              0
# 2014-09-04         7621           1198.98           1198.98              1
# ...                 ...               ...               ...            ...
# 2018-06-20       627389          25096.04          25096.04              5
# 2018-06-22       161342          18075.45          16108.32              8
# 2018-07-06        22295            119.90            119.90              0
# 2018-07-10        47899            649.75            649.75              0
# 2018-07-25       178905           7369.71           7369.71             20
#
# [621 rows x 4 columns]

# %%
def multi_plot(df, title, addAll = True):
    fig = go.Figure()
    for column in df.columns.to_list():
        fig.add_trace(
            go.Scatter(
                x = df.index,
                y = df['id'],
                name = column
            )
        )
    button_all = dict(label = 'All',
                      method = 'update',
                      args = [{'visible':         
    df.columns.isin(df.columns),
                               'title': 'All',
                               'showlegend':True}])
    def create_layout_button(column):
        return dict(label = column,
                    method = 'update',
                    args = [{'visible': df.columns.isin([column]),
                             'title': column,
                             'showlegend': True}])
    fig.update_layout(
        updatemenus=[go.layout.Updatemenu(
            active = 0,
            buttons = ([button_all] * addAll) +  list(df.columns.map(lambda column: create_layout_button(column)))
            )
        ],
         yaxis_type="log"       
    )
    # Update remaining layout properties
    fig.update_layout(
        title_text=title,
        height=800
        
    )
    fig.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
# !{sys.executable} -m pip install datapane
import datapane as dp
# Out:
# ...
#   Created wheel for face: filename=face-20.1.1-py3-none-any.whl size=51091 sha256=1e0f7a68e514c40edb8ac3cacea021ab5b70c82f69bea528cc0d4020b0e93c1d
#   Stored in directory: c:\users\nicole\appdata\local\pip\cache\wheels\67\03\c2\76d2e1e694852ce409ac2938b9f461bc0fdf3789901e7bb1f0
# ...
#   Created wheel for micawber: filename=micawber-0.5.4-py3-none-any.whl size=22373 sha256=25dd5058986b6cbb08cf1441140fbc8b825e1612c29a47a66bbf6c8bad6ac000
#   Stored in directory: c:\users\nicole\appdata\local\pip\cache\wheels\c1\b6\81\f8237c6061ac239fe1079fa35b445460b5ed090f5267fa3a37
# ...
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3587 sha256=43793820504bf093db81cc2c4dc999c61a2a3a368129a26b073df73a42b7d6c6
#   Stored in directory: c:\users\nicole\appdata\local\pip\cache\wheels\86\ab\a3\a8fa7e0a07e80f547e03468c03827f8257f7339327986faed1
# Successfully built face micawber stringcase
# ...

# %%
# !datapane login --token=39cbd95c537fe525d53dc84337873ee25456d057
# Out:
# Connected successfully to https://datapane.com as nicole.a.gregory@gmail.com

# %%
from sqlalchemy import create_engine
url = "postgresql://postgres:MickeyTheAnimal!@final-project.crnuve3iih8x.us-east-1.rds.amazonaws.com:5432/postgres"

engine = create_engine(url)
connect = engine.connect()

query = "SELECT * FROM price_data"

df = pd.read_sql(query, con=connect)
df
# Out:
#        index                    id  prices_amountmax  prices_amountmin  \
# 0          0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1          1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2          2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3          3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4          4  AVpgMuGwLJeJML43KY_c             66.99             66.99
# ...      ...                   ...               ...               ...
# 14587  14587  AVpgibRDLJeJML43PTZX             65.99             65.99
# 14588  14588  AVpgibRDLJeJML43PTZX             58.99             58.99
# 14589  14589  AVpgibRDLJeJML43PTZX             58.49             58.49
# 14590  14590  AVpgibRDLJeJML43PTZX             77.98             77.98
# 14591  14591  AVpgibRDLJeJML43PTZX             71.95             71.95
#
#       prices_availability prices_condition prices_currency prices_dateseen  \
# ...

# %%
df.columns
# Out:
# Index(['index', 'id', 'prices_amountmax', 'prices_amountmin',
#        'prices_availability', 'prices_condition', 'prices_currency',
#        'prices_dateseen', 'prices_issale', 'prices_merchant',
#        'prices_shipping', 'prices_sourceurls', 'asins', 'brand', 'categories',
#        'dateadded', 'dateupdated', 'ean', 'imageurls', 'keys', 'manufacturer',
#        'manufacturernumber', 'name', 'primarycategories', 'sourceurls', 'upc',
#        'weight'],
#       dtype='object')

# %%
id_list = list(df['id'].unique())[:10]

# %%
plt.figure(figsize=(10, 5), dpi=300)

plot_list = [dp.Plot(
    # df[df['id']==id].plot.line(x='prices_dateseen', y='prices_amountmax'), 
    df[df['id'] == id].plot(x='prices_dateseen', y=['prices_amountmax','prices_amountmin']),
    label=id
) for id in id_list]
             
report = dp.Report(
    dp.Select(blocks = plot_list)
).upload(name="App Plot")
# Out:
# Uploading report and associated data - *please wait...*
# Your report only contains a single element - did you know you can include additional plots, tables and text in a single report? More info <a href='https://docs.datapane.com/reports/blocks/layout-pages-and-selects' target='_blank'>here</a>
# Report successfully uploaded. View and share your report <a href='https://datapane.com/reports/mA2vD8A/app-plot/' target='_blank'>here</a>, or edit your report <a href='https://datapane.com/reports/mA2vD8A/app-plot/edit/' target='_blank'>here</a>.
